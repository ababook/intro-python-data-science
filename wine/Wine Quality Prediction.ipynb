# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (13,8)

# %%
df = pd.read_csv("./winequality-red.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   11                    34   0.9978  3.51       0.56
# 1                   25                    67   0.9968  3.20       0.68
# 2                   15                    54   0.9970  3.26       0.65
# 3                   17                    60   0.9980  3.16       0.58
# 4                   11                    34   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# ## Wine Category
# Let's create a new column 'category' which signifies the category of wine - High (1) or Low (0)
#
# Wine with quality > 6 is considered to be High quality, rest are Low quality

# %%
#df.loc[df.b > 0, 'd'] = 1
df.loc[df.quality > 6, 'category'] = 1
df.loc[df.quality <= 6, 'category'] = 0

# %% [markdown]
# This is the frequency count for each category

# %%
df.quality.hist()

# %%
df.category.value_counts()
# Out:
# 0    1382
# 1     217
# Name: category, dtype: int64

# %% [markdown]
# ## Visual Exploration
#
# Let's see how the columns are related
#
# To start, lets take 2 variables at a time to explore data

# %% [markdown]
# ### Fixed Acidity vs pH

# %%
df.plot(x="fixed acidity", y="pH", kind="scatter")

# %% [markdown]
# Exercise: Try more exploring more with different pairs of columns

# %% [markdown]
# ### 3 variable visualization
# Let's add one more dimension to get more sense what is correlated

# %% [markdown]
# ### Alcohol vs Volatile Acidity vs Category

# %%
#df.plot(x="alcohol", y="volatile acidity", kind="scatter", c="category")
ax = df[df.category == 1].plot(x="alcohol", y="volatile acidity", kind="scatter", color="red", label="HIGH")
df[df.category == 0].plot(x="alcohol", y="volatile acidity", kind="scatter", color="green", label="LOW", ax=ax)

# %% [markdown]
# ### Citric Acid vs Volatile Acidity vs Category

# %%
ax = df[df.category == 1].plot(x="citric acid", y="volatile acidity", kind="scatter", color="red", label="HIGH")
df[df.category == 0].plot(x="citric acid", y="volatile acidity", kind="scatter", color="blue", label="LOW", ax=ax)

# %% [markdown]
# Try the same for different columns.
#
# Try to find the combination of columns where you think data points are linearly separable

# %% [markdown]
# Looks like Volatile Acidity & Alcohol impact the category of wine.
#
# Can we confirm?

# %%
grid = sns.FacetGrid(data=df, col="category", hue="category", size=5)
grid.map(plt.scatter, "volatile acidity", "alcohol")

# %% [markdown]
# Can we do the same for citric acid & volatile acidity?

# %% [markdown]
# ### Is there a way to plot all pair of columns at once?

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(df, figsize=(15,15), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3483119910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3482df8f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3482d07650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3482ce7690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3482c6ac10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3482bc05d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3482b4db50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3482accad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3482abb890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3482a3cd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3483471c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34833ffd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34829bc890>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3482928a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34828ac990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34828109d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3482791950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f348277b750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3482682950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34826048d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34825f2450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34825763d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34824da510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f348245a590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3482413610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f348234a550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f34822cc4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34822b0890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3482232810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3482198610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3482122810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34820a4790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3482013310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481f95290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481f793d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481efb450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481eb14d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481dd38d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481d56750>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3481cc6310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481c46e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481c89310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481bb7750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481b38890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481aa9110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481a2c090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34819f6f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481903f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34818c7150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481801050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34817f4f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481764210>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f34816e7190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481642f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34815d6190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f348155a110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f348153ac50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34814bebd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481420d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34813a3d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f348135ce10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481294d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481215cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34811e53d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481166bd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f34810ffbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3481056810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480fd9950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480f4a1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480eca150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480e98fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480e30090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480da6fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480d21110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480ca5090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480c0a2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480b8c250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480b7a050>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3480afb250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480a7d1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34809ded10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480963c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34808c6dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480847e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480800ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34807b8e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f348073bd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34806ad190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f348062f110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480589ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480520110>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f34804a0090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f348046db90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34803fcc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480352910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34802dfb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480262a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34801cfc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480153b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34800c2710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3480043f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347bfdea50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347bf6dad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347bef0a50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f347be5bd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347bdddcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347bd4f850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347bcdd090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347bca7b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347bc34c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347bbb8b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347bb25e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347baa8e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347ba17990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b9a51d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b971cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b8fdd50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f347b801cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b7eefd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b770f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b6dfad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b66d310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b63ae10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b549e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b4cce10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b446150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b3ca0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b3f60d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b304c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b2eda10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f347b273c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b1f6b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b164710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b0e7690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347b04c7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347afce850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347af868d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347af3d810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347ae42790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347ae23b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347ada6ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347ad0e8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347ac97ad0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f347ac19a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347ab885d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347ab0c550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347aaf1690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347aa70710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347aa29790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a9606d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a8e4650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a847a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a7c9990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a7b2790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a739990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a6bc910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f347a62c490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a5ad410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a513550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a4935d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a44c650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a383590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a306510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a2eb8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a26d850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a1d5650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a15f850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a0e17d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f347a04f350>]], dtype=object)

# %% [markdown]
# Does citric acid, volatile acidity & alcohol affect the quality of wine?

# %%
from pandas.tools.plotting import parallel_coordinates

# %%
df_sort = pd.DataFrame()
df_sort["citric acid"] = df_norm["citric acid"]
df_sort["volatile acidity"] = df_norm["volatile acidity"]
df_sort["alcohol"] = df_norm["alcohol"]
df_sort["quality"] = df_norm["quality"]
df_sort["category"] = df_norm["category"]

# %%
plt.figure(figsize=(15,10))
parallel_coordinates(df_sort, 'category', alpha=0.3)

# %%
sns.lmplot(data=df,x="volatile acidity", y="alcohol", hue="category", size=10)

# %% [markdown]
# ### Time to build a predictive model
#
# Let's build a model that can predict the category of wine, given information about alcohol content and volatile acidity

# %% [markdown]
# Building a predictive model involves training the model with historical data known as **training data**. Once we have the model trained, the model can predict labels (in this case, the category of wine) for the given features (test data)
# We have 1600 rows of the wine data, lets split this data into 80:20 ratio as training:testingg data
#
# **Why do we need to do this? **
#
# We can compare the predicted label with the actual label.
# By doing this, we can measure how accurate our model is.

# %%
df.shape
# Out:
# (1599, 13)

# %%
df_train = df.iloc[:1280,]
df_test = df.iloc[1280:,]

# %%
X_train = df_train["volatile acidity"]
y_train = df_train["category"]

# %%
X_test = df_test["volatile acidity"]
y_test = df_test["category"]

# %%
X_train = X_train.reshape(X_train.shape[0],1)
#y_train = y_train.reshape(y_train.shape[0],1)
X_test = X_test.reshape(X_test.shape[0],1)
#y_test = y_test.reshape(y_test.shape[0],1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_model = LogisticRegression()

# %%
logistic_model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predicted = logistic_model.predict(X_test)

# %%
df_compare = pd.DataFrame()
df_compare["actual"] = y_test
df_compare["predicted"] = predicted
df_compare["volatile acidity"] = df_test["volatile acidity"]

# %%
ax=df_compare.plot(x="volatile acidity", y="actual", kind="scatter", color="blue", label="actual")
df_compare.plot(x="volatile acidity", y="predicted", kind="scatter", color="red", label="predicted", ax=ax)

# %% [markdown]
# ![](https://pixabay.com/static/uploads/photo/2013/04/01/09/07/surprise-98460_960_720.png)

# %% [markdown]
# Let's add more features - volatile acidity, citric acid, alcohol to predict the category
